# %%
import numpy as np
import torch
from pathlib import Path
from perception_bev_learning.utils import load_pkl
from os.path import join

EXPERIMENT_FOLDER = "/Data/Results/bev_learning/test_run_all_cfgs/2023-10-17T17-01-15_best_params_regress_elevation_test"


pkl_files = [str(s) for s in Path(EXPERIMENT_FOLDER).glob("*.pkl")]

# LOAD DATA
hdd = {s.split("__")[-1][:-4]: load_pkl(s) for s in pkl_files if s.find("hdd") != -1}
layer_statistics = {
    s.split("__")[-1][:-4]: load_pkl(s) for s in pkl_files if s.find("statistic_reverted_layer_scaling") != -1
}
metrics = {s.split("__")[-1][:-4]: load_pkl(s) for s in pkl_files if s.find("meter_results") != -1}
# Out:
# /home/jonfrey/.local/lib/python3.8/site-packages/scipy/__init__.py:146: UserWarning: A NumPy version >=1.16.5 and <1.23.0 is required for this version of SciPy (detected version 1.23.4
#   warnings.warn(f"A NumPy version >={np_minversion} and <{np_maxversion}"

# %%
MODE = "test"
metrics[MODE].keys()

[k for k in layer_statistics["test"].keys() if k.find("obser") != -1]
# Out:
# ['current_target__observed_mae_bev_metric_elevation_train',
#  'current_target__observed_mae_bev_metric_elevation_val',
#  'current_target__observed_mae_bev_metric_elevation_test',
#  'current_target__observed_mse_bev_metric_wheel_risk_cvar_train',
#  'current_target__observed_mse_bev_metric_wheel_risk_cvar_val',
#  'current_target__observed_mse_bev_metric_wheel_risk_cvar_test',
#  'current_target__unobserved_mae_bev_metric_elevation_train',
#  'current_target__unobserved_mae_bev_metric_elevation_val',
#  'current_target__unobserved_mae_bev_metric_elevation_test',
#  'current_target__unobserved_mse_bev_metric_wheel_risk_cvar_train',
#  'current_target__unobserved_mse_bev_metric_wheel_risk_cvar_val',
#  'current_target__unobserved_mse_bev_metric_wheel_risk_cvar_test',
#  'pred_target__observed_mae_bev_metric_elevation_train',
#  'pred_target__observed_mae_bev_metric_elevation_val',
#  'pred_target__observed_mae_bev_metric_elevation_test',
#  'pred_target__observed_mse_bev_metric_wheel_risk_cvar_train',
#  'pred_target__observed_mse_bev_metric_wheel_risk_cvar_val',
#  'pred_target__observed_mse_bev_metric_wheel_risk_cvar_test',
#  'pred_target__unobserved_mae_bev_metric_elevation_train',
#  'pred_target__unobserved_mae_bev_metric_elevation_val',
#  'pred_target__unobserved_mae_bev_metric_elevation_test',
#  'pred_target__unobserved_mse_bev_metric_wheel_risk_cvar_train',
#  'pred_target__unobserved_mse_bev_metric_wheel_risk_cvar_val',
#  'pred_target__unobserved_mse_bev_metric_wheel_risk_cvar_test']

# %%
from prettytable import PrettyTable

x = PrettyTable()
x.field_names = ["Metric", "Value"]
for k, v in metrics[MODE].items():
    if k.find("_step") == -1:
        x.add_row([k, round(v, 4)])
print(x)
# Out:
# +-------------------------------------------------+--------+
# |                      Metric                     | Value  |
# +-------------------------------------------------+--------+
# |                    test_loss                    | 0.0089 |
# |   test_wheel_risk_cvar_pred_target__mse_epoch   | 0.0072 |
# |   test_wheel_risk_cvar_pred_current__mse_epoch  | 0.0304 |
# |  test_wheel_risk_cvar_current_target__mse_epoch | 0.0183 |
# |   test_wheel_risk_cvar_pred_target__mae_epoch   | 0.0186 |
# |   test_wheel_risk_cvar_pred_current__mae_epoch  | 0.1008 |
# |  test_wheel_risk_cvar_current_target__mae_epoch | 0.0549 |
# |   test_wheel_risk_cvar_pred_target__wmse_epoch  | 0.0073 |
# |  test_wheel_risk_cvar_pred_current__wmse_epoch  | 0.0186 |
# | test_wheel_risk_cvar_current_target__wmse_epoch | 0.0181 |
# |   test_wheel_risk_cvar_pred_target__wmae_epoch  | 0.0187 |
# |  test_wheel_risk_cvar_pred_current__wmae_epoch  | 0.0622 |
# | test_wheel_risk_cvar_current_target__wmae_epoch | 0.0541 |
# |      test_elevation_pred_target__mse_epoch      | 1.2757 |
# |      test_elevation_pred_current__mse_epoch     | 1.8852 |
# |     test_elevation_current_target__mse_epoch    | 0.7189 |
# |      test_elevation_pred_target__mae_epoch      | 0.4121 |
# |      test_elevation_pred_current__mae_epoch     | 0.6293 |
# |     test_elevation_current_target__mae_epoch    | 0.3304 |
# |      test_elevation_pred_target__wmse_epoch     | 1.2668 |
# |     test_elevation_pred_current__wmse_epoch     | 1.0521 |
# |    test_elevation_current_target__wmse_epoch    | 0.7133 |
# |      test_elevation_pred_target__wmae_epoch     | 0.4087 |
# |     test_elevation_pred_current__wmae_epoch     | 0.4509 |
# |    test_elevation_current_target__wmae_epoch    | 0.3285 |
# +-------------------------------------------------+--------+

# %%
from prettytable import PrettyTable
import pandas as pd

# Create a DataFrame from the list of dictionaries


data = {"name": [], "mode": [], "metric": [], "layer": [], "value": []}
for MODE in ["train", "test", "val"]:
    for k, v in metrics[MODE].items():
        if k.find("step") != -1:
            continue
        i1 = k.find("_pred")
        if i1 == -1:
            i1 = k.find("_current")

        i2 = k.find("__")

        data["layer"].append(k[5:i1])
        data["name"].append(k[i1 + 1 : i2])
        data["value"].append(v)
        data["mode"].append(MODE)
        data["metric"].append(k[i2 + 2 : -6])

df = pd.DataFrame.from_dict(data)
df[(df["mode"] == "test") * (df["layer"] == "elevation") * (df["metric"] == "mae")]
metrics[MODE]
# Out:
# {'test_wheel_risk_cvar_pred_target__mse_step': 0.028502963483333588,
#  'test_wheel_risk_cvar_pred_current__mse_step': 0.05561112239956856,
#  'test_wheel_risk_cvar_current_target__mse_step': 0.005698066204786301,
#  'test_wheel_risk_cvar_pred_target__mae_step': 0.055069368332624435,
#  'test_wheel_risk_cvar_pred_current__mae_step': 0.16468492150306702,
#  'test_wheel_risk_cvar_current_target__mae_step': 0.016641052439808846,
#  'test_wheel_risk_cvar_pred_target__wmse_step': 0.029305079951882362,
#  'test_wheel_risk_cvar_pred_current__wmse_step': 0.031414616852998734,
#  'test_wheel_risk_cvar_current_target__wmse_step': 0.005454957485198975,
#  'test_wheel_risk_cvar_pred_target__wmae_step': 0.05629565939307213,
#  'test_wheel_risk_cvar_pred_current__wmae_step': 0.06574390083551407,
#  'test_wheel_risk_cvar_current_target__wmae_step': 0.015160873532295227,
#  'test_elevation_pred_target__mse_step': 0.5742177367210388,
#  'test_elevation_pred_current__mse_step': 5.2266459465026855,
#  'test_elevation_current_target__mse_step': 1.0959186553955078,
#  'test_elevation_pred_target__mae_step': 0.49672582745552063,
#  'test_elevation_pred_current__mae_step': 1.2962238788604736,
#  'test_elevation_current_target__mae_step': 0.5725082755088806,
#  'test_elevation_pred_target__wmse_step': 0.549879252910614,
#  'test_elevation_pred_current__wmse_step': 1.2763062715530396,
#  'test_elevation_current_target__wmse_step': 1.0869090557098389,
#  'test_elevation_pred_target__wmae_step': 0.4884631037712097,
#  'test_elevation_pred_current__wmae_step': 0.6461153030395508,
#  'test_elevation_current_target__wmae_step': 0.5702220797538757,
#  'test_loss': 0.018817001953721046,
#  'test_wheel_risk_cvar_pred_target__mse_epoch': 0.019950158894062042,
#  'test_wheel_risk_cvar_pred_current__mse_epoch': 0.04263580963015556,
#  'test_wheel_risk_cvar_current_target__mse_epoch': 0.029155390337109566,
#  'test_wheel_risk_cvar_pred_target__mae_epoch': 0.04064163193106651,
#  'test_wheel_risk_cvar_pred_current__mae_epoch': 0.13026922941207886,
#  'test_wheel_risk_cvar_current_target__mae_epoch': 0.07301774621009827,
#  'test_wheel_risk_cvar_pred_target__wmse_epoch': 0.020268069580197334,
#  'test_wheel_risk_cvar_pred_current__wmse_epoch': 0.030140018090605736,
#  'test_wheel_risk_cvar_current_target__wmse_epoch': 0.02905886620283127,
#  'test_wheel_risk_cvar_pred_target__wmae_epoch': 0.04106520116329193,
#  'test_wheel_risk_cvar_pred_current__wmae_epoch': 0.0846458449959755,
#  'test_wheel_risk_cvar_current_target__wmae_epoch': 0.07203114777803421,
#  'test_elevation_pred_target__mse_epoch': 0.8702470660209656,
#  'test_elevation_pred_current__mse_epoch': 1.8370987176895142,
#  'test_elevation_current_target__mse_epoch': 1.1840935945510864,
#  'test_elevation_pred_target__mae_epoch': 0.44496065378189087,
#  'test_elevation_pred_current__mae_epoch': 0.7408840656280518,
#  'test_elevation_current_target__mae_epoch': 0.47427651286125183,
#  'test_elevation_pred_target__wmse_epoch': 0.8625568151473999,
#  'test_elevation_pred_current__wmse_epoch': 1.134350299835205,
#  'test_elevation_current_target__wmse_epoch': 1.1753144264221191,
#  'test_elevation_pred_target__wmae_epoch': 0.4410872459411621,
#  'test_elevation_pred_current__wmae_epoch': 0.5482834577560425,
#  'test_elevation_current_target__wmae_epoch': 0.4712386429309845}

# %%
import matplotlib.pyplot as plt

# %matplotlib inline
for MODE in ["train", "val", "test"]:

    # Filter metrics based on keywords
    filtered_elevation_metrics = {}
    filtered_wheel_risk_cvar_metrics = {}

    for k, v in metrics[MODE].items():
        if "pred_target" in k or "current_target" in k:
            if ("_mae_" in k or "_wmae_" in k) and "elevation" in k:
                if "_epoch" in k:
                    filtered_elevation_metrics[k] = v
            elif ("_mse_" in k or "_wmse_" in k) and "wheel_risk_cvar" in k:
                if "_epoch" in k:
                    filtered_wheel_risk_cvar_metrics[k] = v

    # Extract metric names and values for plotting
    elevation_metric_names = list(filtered_elevation_metrics.keys())
    elevation_metric_values = list(filtered_elevation_metrics.values())

    wheel_risk_cvar_metric_names = list(filtered_wheel_risk_cvar_metrics.keys())
    wheel_risk_cvar_metric_values = list(filtered_wheel_risk_cvar_metrics.values())

    # Create a figure with subplots
    fig, axes = plt.subplots(nrows=1, ncols=2, figsize=(16, 6))

    # Bar plot for elevation metrics
    elevation_bar_colors = ["blue" if "current_target" in metric else "orange" for metric in elevation_metric_names]
    axes[0].bar(
        range(len(elevation_metric_names)),
        elevation_metric_values,
        align="center",
        alpha=0.7,
        color=elevation_bar_colors,
    )
    axes[0].set_xticks(range(len(elevation_metric_names)))
    axes[0].set_xticklabels(elevation_metric_names, rotation=0)
    axes[0].set_xlabel("Metric")
    axes[0].set_ylabel("Value")
    axes[0].set_title("Elevation Metrics")
    axes[0].grid(True)
    axes[0].tick_params(axis="x", rotation=45)

    # Bar plot for wheel risk cvar metrics
    wheel_risk_cvar_bar_colors = [
        "blue" if "current_target" in metric else "orange" for metric in wheel_risk_cvar_metric_names
    ]
    axes[1].bar(
        range(len(wheel_risk_cvar_metric_names)),
        wheel_risk_cvar_metric_values,
        align="center",
        alpha=0.7,
        color=wheel_risk_cvar_bar_colors,
    )
    axes[1].set_xticks(range(len(wheel_risk_cvar_metric_names)))
    axes[1].set_xticklabels(wheel_risk_cvar_metric_names, rotation=0)
    axes[1].set_xlabel("Metric")
    axes[1].set_ylabel("Value")
    axes[1].set_title("Wheel Risk CVaR Metrics")
    axes[1].grid(True)
    axes[1].tick_params(axis="x", rotation=45)

    fig.suptitle(f"Metrics for MODE: {MODE}", fontsize=16, y=1.05)
    plt.tight_layout()
    plt.show()

# %%
from perception_bev_learning.dataset import get_bev_dataloader
from perception_bev_learning.cfg import ExperimentParams
from perception_bev_learning.utils import denormalize_img
from perception_bev_learning.visu import LearningVisualizer, show
from perception_bev_learning.visu import show, get_img_from_fig
from pytorch_lightning import seed_everything
import matplotlib.pyplot as plt
from perception_bev_learning.visu import paper_colors_rgb_f

LAYER = "wheel_risk_cvar"
KEY = "bev_metric"

METRICS = ["pred_target__cell_stat", "current_target__cell_stat"]
for MODE in ["train", "val", "test"]:  # , "val", "train"]:
    fig, axes = plt.subplots(1, len(METRICS), sharey=True, figsize=(10, 5))  # Create subplots
    print(LAYER)
    for j, METRIC in enumerate(METRICS):
        # stat = "pred_statistics"
        # stat = "current_statistics"

        recall = layer_statistics[MODE][f"{METRIC}_{KEY}_{LAYER}_test_recall_bins"]
        f1 = layer_statistics[MODE][f"{METRIC}_{KEY}_{LAYER}_test_f1_bins"]
        precision = layer_statistics[MODE][f"{METRIC}_{KEY}_{LAYER}_test_precision_bins"]
        x_values = np.arange(0, len(f1)) + 1
        # Create a figure and a set of subplots

        # Plot hazard_detection_ratio
        axes[j].plot(x_values, [r[1] for r in recall], label="Recall", color=list(paper_colors_rgb_f["orange"]))
        # Plot false_hazard_ratio
        axes[j].plot(x_values, [r[1] for r in f1], label="F1", color=list(paper_colors_rgb_f["magenta"]))
        axes[j].plot(x_values, [r[1] for r in precision], label="Precision", color=list(paper_colors_rgb_f["blue"]))

        # Set labels and title
        axes[j].set_xlabel("Distance in m")
        axes[j].set_ylabel("Metric")
        axes[j].set_title(f"{MODE} - {METRIC} Binning Results")
        axes[j].legend()

    # Display the plot
    plt.tight_layout()  # Adjust layout to prevent overlapping
    plt.show()
# Out:
# Jupyter environment detected. Enabling Open3D WebVisualizer.
# [Open3D INFO] WebRTC GUI backend enabled.
# [Open3D INFO] WebRTCWindowSystem: HTTP handshake server disabled.
# wheel_risk_cvar
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[6], line 21
#      16 print(LAYER)
#      17 for j, METRIC in enumerate(METRICS):
#      18     # stat = "pred_statistics"
#      19     # stat = "current_statistics"
# ---> 21     recall = layer_statistics[MODE][f"{METRIC}_{KEY}_{LAYER}_test_recall_bins"]
#      22     f1 = layer_statistics[MODE][f"{METRIC}_{KEY}_{LAYER}_test_f1_bins"]
#      23     precision = layer_statistics[MODE][f"{METRIC}_{KEY}_{LAYER}_test_precision_bins"]
#
# KeyError: 'pred_target__cell_stat_bev_metric_wheel_risk_cvar_test_recall_bins'

# %%
from perception_bev_learning.dataset import get_bev_dataloader
from perception_bev_learning.cfg import ExperimentParams
from perception_bev_learning.utils import denormalize_img
from perception_bev_learning.visu import LearningVisualizer, show
from perception_bev_learning.visu import show, get_img_from_fig
from pytorch_lightning import seed_everything
import matplotlib.pyplot as plt
from perception_bev_learning.visu import paper_colors_rgb_f

LAYER = "elevation"
KEY = "bev_metric"

METRICS = ["observed_mae", "unobserved_mae"]
MODES = ["test", "val", "train"]
fig, axes = plt.subplots(1, len(METRICS)* len(MODES), sharey=True, figsize=(10, 5))  # Create subplots

for k, MODE in enumerate(MODES):
    print(MODE)
    for j, METRIC in enumerate(METRICS):

            # stat = "pred_statistics"
            # stat = "current_statistics"
            # print("current_target__unobserved_mse_bev_metric_wheel_risk_cvar_test")
            pred_value = layer_statistics[MODE][f"pred_target__{METRIC}_{KEY}_{LAYER}_test"]
            current_value = layer_statistics[MODE][f"current_target__{METRIC}_{KEY}_{LAYER}_test"]
    
            # Get colors from the predefined color palette
    
            # Bar plot for prediction
            axes[j].bar("RoadRunner", pred_value, color=paper_colors_rgb_f["orange"])  
            # Bar plot for target
            axes[j].bar("RACER-X", current_value, color=paper_colors_rgb_f["magenta"])
            # Set the title for each subplot
            axes[j].set_title(METRIC+" " + LAYER)

    # Set the common y-axis label for all subplots
    axes[0].set_ylabel("Values")

    # Show the plots
    plt.show()
# Out:
# test
# val
# train

# %%
layer_statistics[MODE].keys()
# Out:
# dict_keys(['current_target__cell_stat_bev_metric_wheel_risk_cvar_train_mean_map', 'current_target__cell_stat_bev_metric_wheel_risk_cvar_train_var_map', 'current_target__cell_stat_bev_metric_wheel_risk_cvar_train_sum_squared_error', 'current_target__cell_stat_bev_metric_wheel_risk_cvar_train_sum_error', 'current_target__cell_stat_bev_metric_wheel_risk_cvar_train_total', 'current_target__cell_stat_bev_metric_wheel_risk_cvar_train_mean_bins', 'current_target__cell_stat_bev_metric_wheel_risk_cvar_train_var_bins', 'current_target__cell_stat_bev_metric_wheel_risk_cvar_train_sum_squared_error_bins', 'current_target__cell_stat_bev_metric_wheel_risk_cvar_train_sum_error_bins', 'current_target__cell_stat_bev_metric_wheel_risk_cvar_train_total_bins', 'current_target__cell_stat_bev_metric_wheel_risk_cvar_val_mean_map', 'current_target__cell_stat_bev_metric_wheel_risk_cvar_val_var_map', 'current_target__cell_stat_bev_metric_wheel_risk_cvar_val_sum_squared_error', 'current_target__cell_stat_bev_metric_wheel_risk_cvar_val_sum_error', 'current_target__cell_stat_bev_metric_wheel_risk_cvar_val_total', 'current_target__cell_stat_bev_metric_wheel_risk_cvar_val_mean_bins', 'current_target__cell_stat_bev_metric_wheel_risk_cvar_val_var_bins', 'current_target__cell_stat_bev_metric_wheel_risk_cvar_val_sum_squared_error_bins', 'current_target__cell_stat_bev_metric_wheel_risk_cvar_val_sum_error_bins', 'current_target__cell_stat_bev_metric_wheel_risk_cvar_val_total_bins', 'current_target__cell_stat_bev_metric_wheel_risk_cvar_test_mean_map', 'current_target__cell_stat_bev_metric_wheel_risk_cvar_test_var_map', 'current_target__cell_stat_bev_metric_wheel_risk_cvar_test_sum_squared_error', 'current_target__cell_stat_bev_metric_wheel_risk_cvar_test_sum_error', 'current_target__cell_stat_bev_metric_wheel_risk_cvar_test_total', 'current_target__cell_stat_bev_metric_wheel_risk_cvar_test_mean_bins', 'current_target__cell_stat_bev_metric_wheel_risk_cvar_test_var_bins', 'current_target__cell_stat_bev_metric_wheel_risk_cvar_test_sum_squared_error_bins', 'current_target__cell_stat_bev_metric_wheel_risk_cvar_test_sum_error_bins', 'current_target__cell_stat_bev_metric_wheel_risk_cvar_test_total_bins', 'current_target__cell_stat_bev_metric_elevation_train_mean_map', 'current_target__cell_stat_bev_metric_elevation_train_var_map', 'current_target__cell_stat_bev_metric_elevation_train_sum_squared_error', 'current_target__cell_stat_bev_metric_elevation_train_sum_error', 'current_target__cell_stat_bev_metric_elevation_train_total', 'current_target__cell_stat_bev_metric_elevation_train_mean_bins', 'current_target__cell_stat_bev_metric_elevation_train_var_bins', 'current_target__cell_stat_bev_metric_elevation_train_sum_squared_error_bins', 'current_target__cell_stat_bev_metric_elevation_train_sum_error_bins', 'current_target__cell_stat_bev_metric_elevation_train_total_bins', 'current_target__cell_stat_bev_metric_elevation_val_mean_map', 'current_target__cell_stat_bev_metric_elevation_val_var_map', 'current_target__cell_stat_bev_metric_elevation_val_sum_squared_error', 'current_target__cell_stat_bev_metric_elevation_val_sum_error', 'current_target__cell_stat_bev_metric_elevation_val_total', 'current_target__cell_stat_bev_metric_elevation_val_mean_bins', 'current_target__cell_stat_bev_metric_elevation_val_var_bins', 'current_target__cell_stat_bev_metric_elevation_val_sum_squared_error_bins', 'current_target__cell_stat_bev_metric_elevation_val_sum_error_bins', 'current_target__cell_stat_bev_metric_elevation_val_total_bins', 'current_target__cell_stat_bev_metric_elevation_test_mean_map', 'current_target__cell_stat_bev_metric_elevation_test_var_map', 'current_target__cell_stat_bev_metric_elevation_test_sum_squared_error', 'current_target__cell_stat_bev_metric_elevation_test_sum_error', 'current_target__cell_stat_bev_metric_elevation_test_total', 'current_target__cell_stat_bev_metric_elevation_test_mean_bins', 'current_target__cell_stat_bev_metric_elevation_test_var_bins', 'current_ ...

# %%
from perception_bev_learning.dataset import get_bev_dataloader
from perception_bev_learning.cfg import ExperimentParams
from perception_bev_learning.utils import denormalize_img
from perception_bev_learning.visu import LearningVisualizer, show
from perception_bev_learning.visu import show, get_img_from_fig
from pytorch_lightning import seed_everything
import matplotlib.pyplot as plt
from perception_bev_learning.visu import paper_colors_rgb_f


METRICS = ["pred_target__cell_stat", "current_target__cell_stat"]
cut_off = 50
for MODE in ["train", "val", "test"]:  # , "val", "train"]:

    fig, axes = plt.subplots(1, 4, sharey=False, figsize=(14, 3), constrained_layout=False)  # Create subplots

    for k, value in enumerate(["precision", "recall", "f1"]):
        for res in zip(["magenta", "orange"], METRICS, ["RoadRunner", "RACER-X"]):
            if k < 3:

                color, METRIC, axes_label = res
                LAYER = "wheel_risk_cvar"
                KEY = "bev_metric"

                met = layer_statistics[MODE][f"{METRIC}_{KEY}_{LAYER}_test_{value}_bins"]

                x_values = np.arange(0, cut_off) + 1
                # Create a figure and a set of subplots

                # Plot hazard_detection_ratio
                axes[k].plot(
                    x_values, [r[1] for r in met][:cut_off], label=axes_label, color=list(paper_colors_rgb_f[color])
                )

                # Set labels and title
                axes[k].set_xlabel("Distance in [m]")
                axes[k].set_ylabel(value.capitalize())
                axes[k].set_title(f"Hazard Detection: {value.capitalize()}")
                axes[k].legend()
                axes[k].legend(fontsize=10)
                # axes[k].spines['top'].set_visible(False)
                # axes[k].spines['right'].set_visible(False)

                axes[k].set_ylim(bottom=0)
                axes[k].set_ylim(top=1)
                axes[k].set_xlim(left=0)

    # MSE plot
    METRIC_CUR = "current_target__cell_stat"
    METRIC_TAR = "pred_target__cell_stat"
    mean_tar = layer_statistics[MODE][f"{METRIC_TAR}_{KEY}_{LAYER}_test_mean_bins"]
    mean_cur = layer_statistics[MODE][f"{METRIC_CUR}_{KEY}_{LAYER}_test_mean_bins"]

    # Plot hazard_detection_ratio
    axes[3].plot(x_values, mean_tar[:cut_off], label=f"RoadRunner", color=list(paper_colors_rgb_f["magenta"]))
    axes[3].plot(x_values, mean_cur[:cut_off], label=f"RACER-X", color=list(paper_colors_rgb_f["orange"]))

    # Set labels and title
    axes[3].set_xlabel("Distance in [m]", fontsize=12)
    axes[3].set_ylabel("MSE", fontsize=12)
    axes[3].set_title(f"Layer {LAYER}: MSE")
    axes[3].legend(fontsize=10)
    axes[3].grid(True)
    axes[3].set_ylim(bottom=0)

    axes[3].set_ylim(top=0.2)
    axes[3].set_xlim(left=0)

    # axes[1].set_yticklabels([])
    # axes[2].set_yticklabels([])
    # plt.subplots_adjust(wspace=0.0)
    # Display the plot
    # print(MODE)
    plt.tight_layout()  # Adjust layout to prevent overlapping
    plt.savefig(join(EXPERIMENT_FOLDER, f"hazard_detection_metric_{MODE}.svg"), format="svg")
    plt.savefig(join(EXPERIMENT_FOLDER, f"hazard_detection_metric_{MODE}.pdf"), format="pdf")
    plt.show()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[18], line 25
#      22 LAYER = "wheel_risk_cvar"
#      23 KEY = "bev_metric"
# ---> 25 met = layer_statistics[MODE][f"{METRIC}_{KEY}_{LAYER}_test_{value}_bins"]
#      27 x_values = np.arange(0, cut_off) + 1
#      28 # Create a figure and a set of subplots
#      29
#      30 # Plot hazard_detection_ratio
#
# KeyError: 'pred_target__cell_stat_bev_metric_wheel_risk_cvar_test_precision_bins'

# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

for res in zip(["wheel_risk_cvar", "elevation"], ["MSE in [m2]", "MAE in [m]"]):
    LAYER, y_label = res
    MODES = ["train", "val", "test"]
    KEY = "bev_metric"
    METRIC_CUR = "current_target__cell_stat"
    METRIC_TAR = "pred_target__cell_stat"

    fig, axes = plt.subplots(1, len(MODES), sharey=True, figsize=(10, 3))  # Create subplots

    for idx, MODE in enumerate(MODES):
        mean_tar = layer_statistics[MODE][f"{METRIC_TAR}_{KEY}_{LAYER}_test_mean_bins"]
        mean_cur = layer_statistics[MODE][f"{METRIC_CUR}_{KEY}_{LAYER}_test_mean_bins"]

        x_values = np.arange(0, len(mean_cur)) + 1

        # Plot hazard_detection_ratio
        axes[idx].plot(x_values, mean_tar, label=f"RoadRunner", color=list(paper_colors_rgb_f["magenta"]))
        axes[idx].plot(x_values, mean_cur, label=f"RACER-X", color=list(paper_colors_rgb_f["orange"]))

        # Set labels and title
        axes[idx].set_xlabel("Distance in [m]", fontsize=12)
        axes[idx].set_ylabel(y_label, fontsize=12)
        axes[idx].set_title(f"Layer: {LAYER} - Mode: {MODE}")
        axes[idx].legend(fontsize=12)
        axes[idx].grid(True)
        axes[idx].set_ylim(bottom=0)
        if LAYER == "wheel_risk_cvar":
            axes[idx].set_ylim(top=0.2)
        else:
            axes[idx].set_ylim(top=2)
        axes[idx].set_xlim(left=0)

        # axes[idx].spines['top'].set_visible(False)
        # axes[idx].spines['right'].set_visible(False)

    plt.tight_layout()  # Adjust layout to prevent overlapping
    plt.savefig(join(EXPERIMENT_FOLDER, f"{LAYER}_distance.svg"), format="svg")
    plt.savefig(join(EXPERIMENT_FOLDER, f"{LAYER}_distance.pdf"), format="pdf")
    plt.show()

# %%
print(MODE)
MODE = "test"
for MODE in ["test", "train"]:
    layer_statistics[MODE].keys()

    visu = LearningVisualizer(p_visu=EXPERIMENT_FOLDER)

    i1 = visu.plot_elevation_map_two(
        layer_statistics[MODE]["current_target__cell_stat_bev_metric_wheel_risk_cvar_test_mean_map"],
        layer_statistics[MODE]["pred_target__cell_stat_bev_metric_wheel_risk_cvar_test_mean_map"],
        tag=f"{MODE}_epoch_statistic_mae_current_pred_wheel_risk",
        cmap_name="turbo",
        v_max=1,
        v_min=0,
        labels=["RACER-X", "RoadRunner"],
        title="MSE - wheel_risk_cvar",
        store_svg=True,
    )

    def max_nan(t):
        m = ~torch.isnan(t)
        return t[m].max()

    current_mean = layer_statistics[MODE]["current_target__cell_stat_bev_metric_elevation_test_mean_map"]
    pred_mean = layer_statistics[MODE]["pred_target__cell_stat_bev_metric_elevation_test_mean_map"]
    ma = round(float(max(max_nan(current_mean), max_nan(pred_mean))), 3)

    i2 = visu.plot_elevation_map_two(
        current_mean,
        pred_mean,
        tag=f"{MODE}_epoch_statistic_mae_current_pred_elevation",
        cmap_name="turbo",
        v_max=2.5,
        v_min=0,
        labels=["RACER-X", "RoadRunner"],
        title="MSE - wheel_risk_cvar",
        subtitle=False,
        store_svg=True,
    )
    show(i1, title=f"{MODE} - Wheel_Risk"), show(i2, title=f"{MODE} -Elevation")

# %%
[k for k in layer_statistics[MODE].keys() if k.find("mean") != -1]

# %%
import matplotlib.pyplot as plt
import numpy as np

metric = "elevation"
for MODE in ["test", "train"]:
    # 72meter is the max distance consired
    current_mean_bins = layer_statistics[MODE][f"{metric}_current_mean_bins"][:50]
    pred_mean_bins = layer_statistics[MODE][f"{metric}_pred_mean_bins"][:50]

    fig, axs = plt.subplots(1, 2, figsize=(12, 4), sharey=True)
    fig.suptitle(f"{MODE.capitalize()} Data - {metric}")

    # Plot current bins
    axs[0].bar(np.arange(len(current_mean_bins)), current_mean_bins * 20, color="blue", label="Current Bins")
    axs[0].set_xlabel("Bins in meter")
    axs[0].set_ylabel("Values")
    axs[0].set_title("Racer-X Elevation MAE")
    axs[0].legend()

    # Plot predicted bins
    axs[1].bar(np.arange(len(pred_mean_bins)), pred_mean_bins * 20, color="red", label="Pred Bins")
    axs[1].set_xlabel("Bins in meter")
    axs[1].set_ylabel("Values")
    axs[1].set_title("RoadRunner Elevation MAE")
    axs[1].legend()
    plt.tight_layout()
    plt.show()
